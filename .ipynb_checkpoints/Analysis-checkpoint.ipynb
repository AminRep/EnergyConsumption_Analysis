# %% [markdown]
# # Energy Consumption Analysis

# %% [markdown]
# #### Libraries

# %%
import pandas as pd
from datetime import timedelta
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %% [markdown]
# #### Date Prepa

# %%
df = pd.read_csv('Steel_industry_data.csv')
df = df.set_index('date')
df.index = pd.to_datetime(df.index, format='%d/%m/%Y %H:%M')

# There was a problem with dates on main csv file e.g after 2018-01-01 23:45:00 we have 2018-01-01 00:00:00 while we should have 2018-01-02 00:00:00 
# Function to fix the problem
def adjust_date(date):
    # Check if the time is 00:00:00
    if date.time() == pd.Timestamp('00:00:00').time():
        return date + timedelta(days=1)  # Move forward by one day
    else:
        return date  # return the same dates that do not have 00:00:00 as time

# Apply the function to the index
df.index = df.index.map(adjust_date)

df.columns
# Out:
# Index(['Usage_kWh', 'Lagging_Current_Reactive.Power_kVarh',
#        'Leading_Current_Reactive_Power_kVarh', 'CO2(tCO2)',
#        'Lagging_Current_Power_Factor', 'Leading_Current_Power_Factor', 'NSM',
#        'WeekStatus', 'Day_of_week', 'Load_Type'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
# Example: df = pd.read_csv('your_data.csv')

# One-hot encode categorical columns
df_encoded = pd.get_dummies(df, columns=['WeekStatus', 'Day_of_week', 'Load_Type'], drop_first=True)

# Calculate the correlation matrix
corr_matrix = df_encoded.corr()

# Create the heatmap
plt.figure(figsize=(20, 10))
sns.heatmap(corr_matrix, annot=True, cmap='PuBu', fmt='.2f', linewidths=0.5)

# Add title and labels
plt.xticks(rotation=90)
plt.title('Correlation Heatmap with Encoded Categorical Columns')
plt.savefig('dataset heat map')
plt.show()

# %% [markdown]
# # Daily Energy Usage Insights

# %% [markdown]
# ## Average Daily Energy Usage

# %%
df_weekly_avg = df.groupby('Day_of_week')['Usage_kWh'].mean().reset_index()
# Define correct order of weekdays
day_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

# Sort the dataframe by day_order
df_weekly_avg['Day_of_week'] = pd.Categorical(df_weekly_avg['Day_of_week'], categories=day_order, ordered=True)
df_weekly_avg = df_weekly_avg.sort_values('Day_of_week')

# %%
plt.figure(figsize=(16, 8))
plt.bar(df_weekly_avg['Day_of_week'], df_weekly_avg['Usage_kWh'], color="#005b96")

# Formatting the plot
plt.xlabel('Day of the Week')
plt.ylabel('Average Energy Usage (kWh)')
plt.title('Energy Usage by Day of the Week')
plt.xticks(rotation=0)  # Rotate labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig('avg_daily_usage.png')
# Show the plot
plt.show()

# %% [markdown]
# ## Total Daily Energy Usage

# %%
df_weekly_total = df.groupby('Day_of_week')['Usage_kWh'].sum().reset_index()
# Define correct order of weekdays
day_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

# Sort the dataframe by day_order
df_weekly_total['Day_of_week'] = pd.Categorical(df_weekly_total['Day_of_week'], categories=day_order, ordered=True)
df_weekly_total = df_weekly_total.sort_values('Day_of_week')

# %%
plt.figure(figsize=(16, 8))
plt.bar(df_weekly_total['Day_of_week'], df_weekly_total['Usage_kWh'], color="#6497b1")

# Formatting the plot
plt.xlabel('Day of the Week')
plt.ylabel('Total Energy Usage (kWh)')
plt.title('Energy Usage by Day of the Week')
plt.xticks(rotation=0)  # Rotate labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig('total_daily_usage.png')
# Show the plot
plt.show()

# %% [markdown]
# # NSM Analysis

# %%
df = pd.read_csv('Steel_industry_data.csv')
ea = df[['date', 'Usage_kWh']]
ea = ea.set_index('date')
ea.index = pd.to_datetime(ea.index, format='%d/%m/%Y %H:%M')

# There was a problem with dates on main csv file e.g after 2018-01-01 23:45:00 we have 2018-01-01 00:00:00 while we should have 2018-01-02 00:00:00 
# Function to fix the problem
def adjust_date(date):
    # Check if the time is 00:00:00
    if date.time() == pd.Timestamp('00:00:00').time():
        return date + timedelta(days=1)  # Move forward by one day
    else:
        return date  # return the same dates that do not have 00:00:00 as time

# Apply the function to the index
ea.index = ea.index.map(adjust_date)

print(ea.head(100))
# Out:
#                      Usage_kWh
# date
# 2018-01-01 00:15:00       3.17
# 2018-01-01 00:30:00       4.00
# 2018-01-01 00:45:00       3.24
# 2018-01-01 01:00:00       3.31
# 2018-01-01 01:15:00       3.82
# ...                        ...
# 2018-01-02 00:00:00       3.42
# 2018-01-02 00:15:00       3.20
# 2018-01-02 00:30:00       3.85
# 2018-01-02 00:45:00       3.28
# 2018-01-02 01:00:00       3.35
#
# [100 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot first subset
ea.loc[(ea.index >= '2018-05-02 00:15:00') & (ea.index <= '2018-05-03 00:15:00')].plot(ax=ax, style='-', linewidth=0.8, label='Jan 3 - Jan 4')

# Plot second subset on the same axis
ea.loc[(ea.index >= '2018-05-03 00:15:00') & (ea.index <= '2018-05-04 00:15:00')].plot(ax=ax, style='-', color='red', linewidth=0.8, label='Jan 4 - Jan 5')

#
ea.loc[(ea.index >= '2018-05-04 00:15:00') & (ea.index <= '2018-05-05 00:15:00')].plot(ax=ax, style='-', color='gray', linewidth=0.8, label='Jan 5 - Jan 6')
# Show the plot
plt.legend(['Jan 3 - Jan 4', 'Jan 4 - Jan 5', 'Jan 5 - Jan 6'])
plt.show()

# %% [markdown]
# # Power Quality & Efficiency Analysis

# %%
df = pd.read_csv('Steel_industry_data.csv')
df = df.set_index('date')
df.index = pd.to_datetime(df.index, format='%d/%m/%Y %H:%M')
# There was a problem with dates on main csv file e.g after 2018-01-01 23:45:00 we have 2018-01-01 00:00:00 while we should have 2018-01-02 00:00:00 
# Function to fix the problem
def adjust_date(date):
    # Check if the time is 00:00:00
    if date.time() == pd.Timestamp('00:00:00').time():
        return date + timedelta(days=1)  # Move forward by one day
    else:
        return date  # return the same dates that do not have 00:00:00 as time

# Apply the function to the index
df.index = df.index.map(adjust_date)
df['Power_Factor'] = df[['Lagging_Current_Power_Factor', 'Leading_Current_Power_Factor']].mean(axis=1) / 100

# %%
high_pf = df[df['Power_Factor'] > 0.90]
percentage_high_pf = (len(high_pf) / len(df)) * 100
print(f'The above 90% power efficiency of this manufacturing plant during measuring period is: {percentage_high_pf:.2f}%')
# Out:
# The above 90% power efficiency of this manufacturing plant during measuring period is: 39.16%

# %%
# Calculate total energy consumption
total_energy = df['Usage_kWh'].sum()

# Calculate energy consumed when Power Factor > 0.9
efficient_energy = df[df['Power_Factor'] > 0.9]['Usage_kWh'].sum()

# Calculate weighted efficiency percentage
efficiency_percentage = (efficient_energy / total_energy) * 100

print(f"Weighted Energy Efficiency: {efficiency_percentage:.2f}%")
# Out:
# Weighted Energy Efficiency: 87.14%

# %%
# Power Factor plotting in whole dataset 
plt.figure(figsize=(12, 6))
resolution_begin1 = '2018-01-01'
resolution_end1 = '2018-10-30'
plt.plot(df.loc[resolution_begin1:resolution_end1].index, df.loc[resolution_begin1:resolution_end1]['Power_Factor'], linestyle='-', color='g',linewidth=0.8)

plt.xlabel('Date')
plt.ylabel('Power Factor')
plt.title('Power Factor Over Time')
plt.axhline(y=0.9, color='gray', linestyle='--', label='Efficiency Threshold (0.9)')
plt.legend()
plt.grid(True)

plt.show()
fig.savefig('Power Factor Over Time')
# Power factor in one Week plotting
plt.figure(figsize=(12, 6))
resolution_begin2 = '2018-05-01'
resolution_end2 = '2018-05-07'
plt.plot(df.loc[resolution_begin2:resolution_end2].index, df.loc[resolution_begin2:resolution_end2]['Power_Factor'], linestyle='-', color='g',linewidth=0.8)

plt.xlabel('Days')
plt.ylabel('Power Factor')
plt.title('Power Factor Changes in One Week')
plt.axhline(y=0.9, color='gray', linestyle='--', label='Efficiency Threshold (0.9)')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True)

plt.show()
fig.savefig('Power Factor Changes in One Week.png')

# %% [markdown]
# # Carbon Footprint & Sustainability

# %%
df = pd.read_csv('Steel_industry_data.csv')
df = df.set_index('date')
df.index = pd.to_datetime(df.index, format='%d/%m/%Y %H:%M')

# There was a problem with dates on main csv file e.g after 2018-01-01 23:45:00 we have 2018-01-01 00:00:00 while we should have 2018-01-02 00:00:00 
# Function to fix the problem
def adjust_date(date):
    # Check if the time is 00:00:00
    if date.time() == pd.Timestamp('00:00:00').time():
        return date + timedelta(days=1)  # Move forward by one day
    else:
        return date  # return the same dates that do not have 00:00:00 as time

# Apply the function to the index
df.index = df.index.map(adjust_date)
df.head(100)
# Out:
#                      Usage_kWh  Lagging_Current_Reactive.Power_kVarh  \
# date
# 2018-01-01 00:15:00       3.17                                  2.95
# 2018-01-01 00:30:00       4.00                                  4.46
# 2018-01-01 00:45:00       3.24                                  3.28
# 2018-01-01 01:00:00       3.31                                  3.56
# 2018-01-01 01:15:00       3.82                                  4.50
# ...                        ...                                   ...
# 2018-01-02 00:00:00       3.42                                  3.46
# 2018-01-02 00:15:00       3.20                                  3.10
# 2018-01-02 00:30:00       3.85                                  4.61
# 2018-01-02 00:45:00       3.28                                  3.67
# 2018-01-02 01:00:00       3.35                                  3.60
#
#                      Leading_Current_Reactive_Power_kVarh  CO2(tCO2)  \
# date
# 2018-01-01 00:15:00                                   0.0        0.0
# 2018-01-01 00:30:00                                   0.0        0.0
# 2018-01-01 00:45:00                                   0.0        0.0
# 2018-01-01 01:00:00                                   0.0        0.0
# 2018-01-01 01:15:00                                   0.0        0.0
# ...                                                   ...        ...
# 2018-01-02 00:00:00                                   0.0        0.0
# 2018-01-02 00:15:00                                   0.0        0.0
# 2018-01-02 00:30:00                                   0.0        0.0
# 2018-01-02 00:45:00                                   0.0        0.0
# 2018-01-02 01:00:00                                   0.0        0.0
#
#                      Lagging_Current_Power_Factor  \
# date
# 2018-01-01 00:15:00                         73.21
# 2018-01-01 00:30:00                         66.77
# 2018-01-01 00:45:00                         70.28
# 2018-01-01 01:00:00                         68.09
# 2018-01-01 01:15:00                         64.72
# ...                                           ...
# 2018-01-02 00:00:00                         70.30
# 2018-01-02 00:15:00                         71.82
# 2018-01-02 00:30:00                         64.10
# 2018-01-02 00:45:00                         66.64
# 2018-01-02 01:00:00                         68.12
#
#                      Leading_Current_Power_Factor   NSM WeekStatus  \
# date
# 2018-01-01 00:15:00                         100.0   900    Weekday
# 2018-01-01 00:30:00                         100.0  1800    Weekday
# 2018-01-01 00:45:00                         100.0  2700    Weekday
# 2018-01-01 01:00:00                         100.0  3600    Weekday
# 2018-01-01 01:15:00                         100.0  4500    Weekday
# ...                                           ...   ...        ...
# 2018-01-02 00:00:00                         100.0     0    Weekday
# 2018-01-02 00:15:00                         100.0   900    Weekday
# 2018-01-02 00:30:00                         100.0  1800    Weekday
# 2018-01-02 00:45:00                         100.0  2700    Weekday
# 2018-01-02 01:00:00                         100.0  3600    Weekday
#
#                     Day_of_week   Load_Type
# date
# 2018-01-01 00:15:00      Monday  Light_Load
# 2018-01-01 00:30:00      Monday  Light_Load
# 2018-01-01 00:45:00      Monday  Light_Load
# 2018-01-01 01:00:00      Monday  Light_Load
# 2018-01-01 01:15:00      Monday  Light_Load
# ...                         ...         ...
# 2018-01-02 00:00:00      Monday  Light_Load
# 2018-01-02 00:15:00     Tuesday  Light_Load
# 2018-01-02 00:30:00     Tuesday  Light_Load
# 2018-01-02 00:45:00     Tuesday  Light_Load
# 2018-01-02 01:00:00     Tuesday  Light_Load
#
# [100 rows x 10 columns]

# %%
light_load_co2 = df[df['Load_Type'] == 'Light_Load']['CO2(tCO2)'].sum()
med_load_co2 = df[df['Load_Type'] == 'Medium_Load']['CO2(tCO2)'].sum()
max_load_co2 = df[df['Load_Type'] == 'Maximum_Load']['CO2(tCO2)'].sum()

# %%
import matplotlib.pyplot as plt

# Data
labels = ['Light Load', 'Medium Load', 'Maximum Load']
co2_values = [light_load_co2, med_load_co2, max_load_co2]

# Plot
plt.figure(figsize=(6, 6))  # Set figure size
plt.pie(co2_values, labels=labels, autopct='%1.1f%%', startangle=140, colors=['lightblue', 'orange', 'red'])

# Title
plt.title('CO2 Emissions by Load Type')

# Show plot
plt.show()

# %% [markdown]
# # Features Analysis

# %%
df = pd.read_csv('Steel_industry_data.csv')
df = df.set_index('date')
df.index = pd.to_datetime(df.index, format='%d/%m/%Y %H:%M')

# There was a problem with dates on main csv file e.g after 2018-01-01 23:45:00 we have 2018-01-01 00:00:00 while we should have 2018-01-02 00:00:00 
# Function to fix the problem
def adjust_date(date):
    # Check if the time is 00:00:00
    if date.time() == pd.Timestamp('00:00:00').time():
        return date + timedelta(days=1)  # Move forward by one day
    else:
        return date  # return the same dates that do not have 00:00:00 as time

# Apply the function to the index
df.index = df.index.map(adjust_date)

# %%
def split_date(df):
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['month'] = df.index.month
    return df

# %%
df = split_date(df)

# %%
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data = df, x = 'hour', y = 'Usage_kWh',whis=(0, 100), color= "#005b96")
ax.set_title('Hourly Power Consumption')
# Out:
# Text(0.5, 1.0, 'Hourly Power Consumption')

# %%
fig, ax = plt.subplots(figsize=(16, 8))
sns.boxplot(data = df, x = 'Day of the Week', y = 'Usage_kWh',whis=(0, 100), color = "#005b96")
ax.set_title('Daily energy Consumption')
fig.savefig('boxplot_daily_usage.png')

# %%
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data = df, x = 'month', y = 'Usage_kWh',whis=(0, 100))
ax.set_title('monthly Power Consumption')
# Out:
# Text(0.5, 1.0, 'monthly Power Consumption')

# %%
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data = df, x = 'month', y = 'CO2(tCO2)',whis=(0, 100))
ax.set_title('monthly carbon footprint')
# Out:
# Text(0.5, 1.0, 'monthly carbon footprint')

# %%
df['Power_Factor'] = df[['Lagging_Current_Power_Factor', 'Leading_Current_Power_Factor']].mean(axis=1) / 100

fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data = df, x = 'month', y = 'Power_Factor')
ax.set_title('monthly power factor')
# Out:
# Text(0.5, 1.0, 'monthly power factor')

# %% [markdown]
# # Model Creating

# %%
df = pd.read_csv('Steel_industry_data.csv')
df = df.set_index('date')
df.index = pd.to_datetime(df.index, format='%d/%m/%Y %H:%M')

# There was a problem with dates on main csv file e.g after 2018-01-01 23:45:00 we have 2018-01-01 00:00:00 while we should have 2018-01-02 00:00:00 
# Function to fix the problem
def adjust_date(date):
    # Check if the time is 00:00:00
    if date.time() == pd.Timestamp('00:00:00').time():
        return date + timedelta(days=1)  # Move forward by one day
    else:
        return date  # return the same dates that do not have 00:00:00 as time

# Apply the function to the index
df.index = df.index.map(adjust_date)
# Drop 'Day_of_week' column
df = df.drop(columns=['Day_of_week'])

# Convert categorical columns to numeric
encoder = LabelEncoder()
df['WeekStatus'] = encoder.fit_transform(df['WeekStatus'])
df['Load_Type'] = encoder.fit_transform(df['Load_Type'])

# %%
train_data = df.loc[df.index<'2018-11-01']
test_data = df.loc[df.index >= '2018-11-01']

# %%
fig, ax = plt.subplots(figsize=(60,25))
train_data.plot(ax = ax, label = 'training data')
test_data.plot(ax = ax, label = 'testing data')
plt.show()

# %%
def split_date(df):
    df = df.copy() # create a copy to prevent slice from data base error
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['month'] = df.index.month
    return df
train = split_date(train_data)
test = split_date(test_data)
train.columns
# Out:
# Index(['Usage_kWh', 'Lagging_Current_Reactive.Power_kVarh',
#        'Leading_Current_Reactive_Power_kVarh', 'CO2(tCO2)',
#        'Lagging_Current_Power_Factor', 'Leading_Current_Power_Factor', 'NSM',
#        'WeekStatus', 'Load_Type', 'hour', 'dayofweek', 'month'],
#       dtype='object')

# %%
FEATURES = ['Lagging_Current_Reactive.Power_kVarh',
       'Leading_Current_Reactive_Power_kVarh', 'CO2(tCO2)',
       'Lagging_Current_Power_Factor', 'Leading_Current_Power_Factor', 'NSM',
       'WeekStatus', 'Load_Type', 'hour', 'dayofweek', 'month']
TARGET = ['Usage_kWh']

# %%
X_train =  train[FEATURES]
Y_train = train[TARGET]

X_test =  test[FEATURES]
Y_test = test[TARGET]

# %%
reg = xgb.XGBRegressor(
    n_estimators=10000, 
    learning_rate=0.07,  
    max_depth=5,  
    min_child_weight=8,  
    subsample=0.85,  
    colsample_bytree=0.85,  
    reg_lambda=2,  
    reg_alpha=1,  
    early_stopping_rounds=200,  
    random_state=42
)

reg.fit(X_train, Y_train, 
        eval_set=[(X_train, Y_train), (X_test, Y_test)], 
        verbose=100)
# Out:
# [0]	validation_0-rmse:31.54348	validation_1-rmse:29.12084
# [100]	validation_0-rmse:2.01603	validation_1-rmse:1.97187
# [200]	validation_0-rmse:1.48493	validation_1-rmse:1.52260
# [300]	validation_0-rmse:1.20813	validation_1-rmse:1.30282
# [400]	validation_0-rmse:1.02616	validation_1-rmse:1.16068
# [500]	validation_0-rmse:0.89139	validation_1-rmse:1.06445
# [600]	validation_0-rmse:0.79494	validation_1-rmse:0.99923
# [700]	validation_0-rmse:0.71938	validation_1-rmse:0.94635
# [800]	validation_0-rmse:0.66353	validation_1-rmse:0.90867
# [900]	validation_0-rmse:0.61815	validation_1-rmse:0.87839
# [1000]	validation_0-rmse:0.58124	validation_1-rmse:0.85519
# [1100]	validation_0-rmse:0.54879	validation_1-rmse:0.83056
# [1200]	validation_0-rmse:0.52161	validation_1-rmse:0.81022
# [1300]	validation_0-rmse:0.49795	validation_1-rmse:0.79620
# [1400]	validation_0-rmse:0.47514	validation_1-rmse:0.78171
# [1500]	validation_0-rmse:0.45687	validation_1-rmse:0.77224
# [1600]	validation_0-rmse:0.44072	validation_1-rmse:0.76583
# [1700]	validation_0-rmse:0.42556	validation_1-rmse:0.75635
# [1800]	validation_0-rmse:0.41207	validation_1-rmse:0.74949
# [1900]	validation_0-rmse:0.39944	validation_1-rmse:0.74045
# [2000]	validation_0-rmse:0.38880	validation_1-rmse:0.73228
# [2100]	validation_0-rmse:0.37836	validation_1-rmse:0.72867
# [2200]	validation_0-rmse:0.36877	validation_1-rmse:0.72394
# [2300]	validation_0-rmse:0.36015	validation_1-rmse:0.72253
# [2400]	validation_0-rmse:0.35222	validation_1-rmse:0.71777
# [2500]	validation_0-rmse:0.34438	validation_1-rmse:0.71266
# [2600]	validation_0-rmse:0.33724	validation_1-rmse:0.71095
# [2700]	validation_0-rmse:0.33043	validation_1-rmse:0.70796
# [2800]	validation_0-rmse:0.32365	validation_1-rmse:0.70500
# [2900]	validation_0-rmse:0.31732	validation_1-rmse:0.70100
# [3000]	validation_0-rmse:0.31169	validation_1-rmse:0.69950
# [3100]	validation_0-rmse:0.30615	validation_1-rmse:0.69654
# [3200]	validation_0-rmse:0.30089	validation_1-rmse:0.69477
# [3300]	validation_0-rmse:0.29611	validation_1-rmse:0.69298
# [3400]	validation_0-rmse:0.29136	validation_1-rmse:0.69089
# [3500]	validation_0-rmse:0.28636	validation_1-rmse:0.68971
# [3600]	validation_0-rmse:0.28200	validation_1-rmse:0.68858
# [3700]	validation_0-rmse:0.27779	validation_1-rmse:0.68783
# [3800]	validation_0-rmse:0.27355	validation_1-rmse:0.68679
# [3900]	validation_0-rmse:0.26952	validation_1-rmse:0.68435
# [4000]	validation_0-rmse:0.26573	validation_1-rmse:0.68266
# [4100]	validation_0-rmse:0.26182	validation_1-rmse:0.68110
# [4200]	validation_0-rmse:0.25809	validation_1-rmse:0.67930
# [4300]	validation_0-rmse:0.25479	validation_1-rmse:0.67783
# [4400]	validation_0-rmse:0.25146	validation_1-rmse:0.67746
# [4500]	validation_0-rmse:0.24857	validation_1-rmse:0.67627
# [4600]	validation_0-rmse:0.24534	validation_1-rmse:0.67444
# [4700]	validation_0-rmse:0.24262	validation_1-rmse:0.67332
# [4800]	validation_0-rmse:0.23995	validation_1-rmse:0.67325
# [4900]	validation_0-rmse:0.23726	validation_1-rmse:0.67284
# [5000]	validation_0-rmse:0.23453	validation_1-rmse:0.67246
# [5100]	validation_0-rmse:0.23207	validation_1-rmse:0.67230
# [5200]	validation_0-rmse:0.22958	validation_1-rmse:0.67190
# [5300]	validation_0-rmse:0.22717	validation_1-rmse:0.67163
# [5400]	validation_0-rmse:0.22477	validation_1-rmse:0.67059
# [5500]	validation_0-rmse:0.22249	validation_1-rmse:0.66970
# [5600]	validation_0-rmse:0.22013	validation_1-rmse:0.66893
# [5700]	validation_0-rmse:0.21794	validation_1-rmse:0.66864
# [5800]	validation_0-rmse:0.21577	validation_1-rmse:0.66797
# [5900]	validation_0-rmse:0.21368	validation_1-rmse:0.66776
# [6000]	validation_0-rmse:0.21166	validation_1-rmse:0.66755
# [6100]	validation_0-rmse:0.20969	validation_1-rmse:0.66659
# [6200]	validation_0-rmse:0.20779	validation_1-rmse:0.66694
# [6300]	validation_0-rmse:0.20591	validation_1-rmse:0.66624
# [6400]	validation_0-rmse:0.20424	validation_1-rmse:0.66580
# [6500]	validation_0-rmse:0.20256	validation_1-rmse:0.66618
# [6589]	validation_0-rmse:0.20108	validation_1-rmse:0.66622
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.85, device=None, early_stopping_rounds=200,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.07, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=8, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=10000, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
test['Predictions'] = reg.predict(X_test)

# Instead of merging, assign directly
df['Predictions'] = test['Predictions']

ax = df[['Usage_kWh']].plot(figsize=(20,5))
df['Predictions'].plot(ax=ax, style='.', color='orange')

plt.legend(['true value', 'predicted value'])
ax.set_title('Model prediction vs true data comparison')  # Fixed settitle -> set_title

plt.show()

ax = df.loc[(df.index > '2018-11-01') & (df.index < '2018-11-08')]['Usage_kWh'].plot(
    figsize=(20, 5), style='o-', color='blue', linewidth=1, label='Actual Usage kWh', markersize=8)

df.loc[(df.index > '2018-11-01') & (df.index < '2018-11-08')]['Predictions'].plot(
    style='*', color='orange', linewidth=1, label='Predictions', markersize=5)

plt.title('Week of Predictions', fontsize=16)
plt.xlabel('Days', fontsize=14)
plt.ylabel('kWh', fontsize=14)
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Final Model Metrics

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Predicting the target variable on the test data
Y_pred = reg.predict(X_test)

# Calculate MAE, MSE, RMSE, and R²
mae = mean_absolute_error(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(Y_test, Y_pred)

# Display the results
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 0.3541
# Mean Squared Error (MSE): 0.4431
# Root Mean Squared Error (RMSE): 0.6656
# R-squared (R²): 0.9995
